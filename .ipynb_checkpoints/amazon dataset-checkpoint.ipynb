# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Downloads\amazon_ecommerce_sample_100k.csv")
eda_df = df.copy()

# %%
eda_df.head()
# Out:
#    Order_ID  Customer_ID  Age  Gender   Region Product_Category  Product_ID  \
# 0   1000001        18032   47  Female   Jaipur          Grocery        2240
# 1   1000002        79655   39  Female  Kolkata             Toys        4702
# 2   1000003        68910   18    Male  Kolkata             Home        9728
# 3   1000004        49498   49  Female     Pune            Books        7899
# 4   1000005        48970   65  Female  Chennai             Home        1790
#
#       Price  Quantity  Discount_Percent  Rating Payment_Method  Delivery_Days  \
# 0   9244.26         2                37     3.3    Credit Card              6
# 1  13615.80         3                 2     2.5            UPI             12
# 2  24870.09         5                32     3.9            COD              1
# 3  48378.12         4                49     1.1     Debit Card              5
# 4  26626.15         4                19     2.2            UPI              7
#
#    Returned  Prime_Member  Seller_Rating  Order_Month   Revenue
# 0         0             1            3.9            6  11647.77
# 1         0             1            3.1            3  40030.45
# 2         0             1            4.0            1  84558.31
# 3         1             0            3.8            3  98691.36
# 4         0             1            2.8            5  86268.73

# %%
eda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          100000 non-null  int64
#  1   Customer_ID       100000 non-null  int64
#  2   Age               100000 non-null  int64
#  3   Gender            100000 non-null  object
#  4   Region            100000 non-null  object
#  5   Product_Category  100000 non-null  object
#  6   Product_ID        100000 non-null  int64
#  7   Price             100000 non-null  float64
#  8   Quantity          100000 non-null  int64
#  9   Discount_Percent  100000 non-null  int64
#  10  Rating            100000 non-null  float64
#  11  Payment_Method    100000 non-null  object
#  12  Delivery_Days     100000 non-null  int64
#  13  Returned          100000 non-null  int64
#  14  Prime_Member      100000 non-null  int64
#  15  Seller_Rating     100000 non-null  float64
#  16  Order_Month       100000 non-null  int64
#  17  Revenue           100000 non-null  float64
# dtypes: float64(4), int64(10), object(4)
# memory usage: 13.7+ MB

# %%
eda_df.drop(columns=['Order_ID' , 'Customer_ID' , 'Product_ID'] , axis=1 , inplace=True)

# %%
eda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Age               100000 non-null  int64
#  1   Gender            100000 non-null  object
#  2   Region            100000 non-null  object
#  3   Product_Category  100000 non-null  object
#  4   Price             100000 non-null  float64
#  5   Quantity          100000 non-null  int64
#  6   Discount_Percent  100000 non-null  int64
#  7   Rating            100000 non-null  float64
#  8   Payment_Method    100000 non-null  object
#  9   Delivery_Days     100000 non-null  int64
#  10  Returned          100000 non-null  int64
#  11  Prime_Member      100000 non-null  int64
#  12  Seller_Rating     100000 non-null  float64
#  13  Order_Month       100000 non-null  int64
#  14  Revenue           100000 non-null  float64
# dtypes: float64(4), int64(7), object(4)
# memory usage: 11.4+ MB

# %%
eda_df.describe()
# Out:
#                  Age          Price       Quantity  Discount_Percent  \
# count  100000.000000  100000.000000  100000.000000     100000.000000
# mean       43.559100   24995.694153       2.990660         25.042250
# std        14.999346   14386.476643       1.414508         14.696979
# min        18.000000     100.120000       1.000000          0.000000
# 25%        31.000000   12589.592500       2.000000         12.000000
# 50%        44.000000   24919.460000       3.000000         25.000000
# 75%        56.000000   37471.447500       4.000000         38.000000
# max        69.000000   49999.630000       5.000000         50.000000
#
#               Rating  Delivery_Days       Returned   Prime_Member  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        3.004242       7.486890       0.102600       0.599150
# std         1.152577       4.026635       0.303437       0.490073
# min         1.000000       1.000000       0.000000       0.000000
# 25%         2.000000       4.000000       0.000000       0.000000
# 50%         3.000000       8.000000       0.000000       1.000000
# 75%         4.000000      11.000000       0.000000       1.000000
# max         5.000000      14.000000       1.000000       1.000000
#
#        Seller_Rating    Order_Month        Revenue
# count  100000.000000  100000.000000  100000.000000
# mean        3.752008       6.483910   55991.679961
# std         0.723327       3.449122   46508.117105
# min         2.500000       1.000000      51.670000
# 25%         3.100000       3.000000   19753.852500
# 50%         3.800000       6.000000   42555.025000
# 75%         4.400000       9.000000   81903.352500
# max         5.000000      12.000000  249865.700000

# %%
eda_df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Region              0
# Product_Category    0
# Price               0
# Quantity            0
# Discount_Percent    0
# Rating              0
# Payment_Method      0
# Delivery_Days       0
# Returned            0
# Prime_Member        0
# Seller_Rating       0
# Order_Month         0
# Revenue             0
# Discounted_Price    0
# Age_Group           0
# dtype: int64

# %%
eda_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
eda_df['Discounted_Price'] = eda_df['Price'] - eda_df['Price']*eda_df['Discount_Percent']/100

# %%
eda_df
# Out:
#        Age  Gender     Region Product_Category     Price  Quantity  \
# 0       47  Female     Jaipur          Grocery   9244.26         2
# 1       39  Female    Kolkata             Toys  13615.80         3
# 2       18    Male    Kolkata             Home  24870.09         5
# 3       49  Female       Pune            Books  48378.12         4
# 4       65  Female    Chennai             Home  26626.15         4
# ...    ...     ...        ...              ...       ...       ...
# 99995   24  Female    Chennai      Electronics  46089.60         5
# 99996   64    Male      Delhi           Sports  37953.28         1
# 99997   66    Male  Bangalore           Sports  45632.65         1
# 99998   69    Male    Chennai          Grocery  26058.37         5
# 99999   66    Male      Delhi           Beauty  20511.58         2
#
#        Discount_Percent  Rating Payment_Method  Delivery_Days  Returned  \
# 0                    37     3.3    Credit Card              6         0
# 1                     2     2.5            UPI             12         0
# 2                    32     3.9            COD              1         0
# 3                    49     1.1     Debit Card              5         1
# 4                    19     2.2            UPI              7         0
# ...                 ...     ...            ...            ...       ...
# 99995                28     4.7    Net Banking              9         0
# 99996                 4     4.2    Net Banking              3         0
# 99997                20     2.7    Credit Card              8         0
# 99998                22     2.5     Debit Card              4         0
# 99999                45     3.9    Credit Card              4         0
#
#        Prime_Member  Seller_Rating  Order_Month    Revenue  Discounted_Price
# 0                 1            3.9            6   11647.77         5823.8838
# 1                 1            3.1            3   40030.45        13343.4840
# 2                 1            4.0            1   84558.31        16911.6612
# 3                 0            3.8            3   98691.36        24672.8412
# 4                 1            2.8            5   86268.73        21567.1815
# ...             ...            ...          ...        ...               ...
# 99995             1            3.9            5  165922.56        33184.5120
# 99996             1            2.5            3   36435.15        36435.1488
# 99997             1            4.7           10   36506.12        36506.1200
# 99998             0            2.9            1  101627.64        20325.5286
# 99999             1            2.6            9   22562.74        11281.3690
#
# [100000 rows x 16 columns]

# %%
eda_df.groupby('Region')['Price'].sum()
# Out:
# Region
# Bangalore    3.070412e+08
# Chennai      3.100921e+08
# Delhi        3.117570e+08
# Hyderabad    3.179187e+08
# Jaipur       3.103221e+08
# Kolkata      3.124333e+08
# Mumbai       3.134870e+08
# Pune         3.165179e+08
# Name: Price, dtype: float64

# %%
eda_df.groupby('Region')['Discounted_Price'].sum()
# Out:
# Region
# Bangalore    2.303915e+08
# Chennai      2.327410e+08
# Delhi        2.338411e+08
# Hyderabad    2.387178e+08
# Jaipur       2.326528e+08
# Kolkata      2.347654e+08
# Mumbai       2.342426e+08
# Pune         2.366762e+08
# Name: Discounted_Price, dtype: float64

# %%
payment_counts = eda_df['Payment_Method'].value_counts()

payment_counts
# Out:
# Payment_Method
# UPI            20212
# Debit Card     20181
# Net Banking    19949
# COD            19881
# Credit Card    19777
# Name: count, dtype: int64

# %%
bar1 = plt.bar(payment_counts.index, payment_counts.values , color='orange')
plt.bar_label(bar1)
plt.xlabel('Payment Methods')
plt.ylabel('No of Transactions')
plt.show()

# %% [markdown]
# ## All payment methods has almost equal number of transactions

# %%
revenue_per_method = eda_df.groupby('Payment_Method')['Discounted_Price'].sum()
revenue_per_method
# Out:
# Payment_Method
# COD            3.720007e+08
# Credit Card    3.716724e+08
# Debit Card     3.802464e+08
# Net Banking    3.735002e+08
# UPI            3.766087e+08
# Name: Discounted_Price, dtype: float64

# %%
bar2 = plt.bar(revenue_per_method.index, revenue_per_method.values , color='red')
plt.bar_label(bar2)
plt.xlabel('Payment Methods')
plt.ylabel('Total Revenue Generated')
plt.show()

# %%
labelsAge = [f'{i} - {i+12}' for i in range(0, 61, 12)]
print(labelsAge)
# Out:
# ['0 - 12', '12 - 24', '24 - 36', '36 - 48', '48 - 60', '60 - 72']

# %%
eda_df["Age_Group"] = pd.cut(eda_df.Age , labels=labelsAge, bins=range(0,80,12))

# %%
ageGroupBar = plt.bar(labelsAge , eda_df.Age_Group.value_counts().sort_index() , color='green')
plt.bar_label(ageGroupBar)
plt.xlabel("Lables")
plt.ylabel("Age Counts")
plt.title("Age Counts")
plt.show()

# %% [markdown]
# ## Age groups from 24-60 are highly active while Age Group from 12-24 & 60-72 are slightly lower active

# %%
revenue_age_group = eda_df.groupby('Age_Group' , observed=True)['Revenue'].sum()
revenue_age_group
# Out:
# Age_Group
# 12 - 24    7.465896e+08
# 24 - 36    1.292378e+09
# 36 - 48    1.287402e+09
# 48 - 60    1.299661e+09
# 60 - 72    9.731375e+08
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.bar(revenue_age_group.index.astype(str),
        revenue_age_group.values)

plt.xlabel("Age Group")
plt.ylabel("Total Revenue")
plt.title("Revenue by Age Group")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 48–60 age group generates the highest revenue.
# ### 24–60 age range is the strongest customer segment.

# %%
revenue_by_gender = eda_df.groupby('Gender')['Revenue'].sum()
revenue_by_gender
# Out:
# Gender
# Female    2.788682e+09
# Male      2.697103e+09
# Other     1.133828e+08
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(8,8))

plt.pie(
    revenue_by_gender.values,
    labels=revenue_by_gender.index,
    autopct='%1.1f%%'
)

plt.title("Revenue Distribution by Gender")
plt.show()

# %%
eda_df.corr(numeric_only=True)
# Out:
#                        Age     Price  Quantity  Discount_Percent    Rating  \
# Age               1.000000 -0.002915  0.001700         -0.000707 -0.001697
# Price            -0.002915  1.000000 -0.005443         -0.001927  0.002910
# Quantity          0.001700 -0.005443  1.000000         -0.003755 -0.002941
# Discount_Percent -0.000707 -0.001927 -0.003755          1.000000  0.002100
# Rating           -0.001697  0.002910 -0.002941          0.002100  1.000000
# Delivery_Days    -0.002688  0.003160 -0.002871         -0.002040  0.001794
# Returned         -0.000506  0.001360 -0.004431          0.003345  0.006439
# Prime_Member      0.002924  0.002638  0.000802         -0.000039  0.002876
# Seller_Rating     0.002097  0.000760  0.002739         -0.002905  0.001383
# Order_Month       0.001701 -0.001233 -0.005087         -0.003613  0.006376
# Revenue           0.000752  0.689759  0.566865         -0.241062 -0.000515
# Discounted_Price -0.003095  0.930470 -0.003302         -0.319363  0.001490
#
#                   Delivery_Days  Returned  Prime_Member  Seller_Rating  \
# Age                   -0.002688 -0.000506      0.002924       0.002097
# Price                  0.003160  0.001360      0.002638       0.000760
# Quantity              -0.002871 -0.004431      0.000802       0.002739
# Discount_Percent      -0.002040  0.003345     -0.000039      -0.002905
# Rating                 0.001794  0.006439      0.002876       0.001383
# Delivery_Days          1.000000 -0.004145     -0.001642      -0.001325
# Returned              -0.004145  1.000000      0.005563       0.002802
# Prime_Member          -0.001642  0.005563      1.000000      -0.004092
# Seller_Rating         -0.001325  0.002802     -0.004092       1.000000
# Order_Month           -0.000608 -0.002025      0.001393       0.006533
# Revenue                0.000535 -0.001021      0.001110       0.003189
# Discounted_Price       0.003852  0.000267      0.002219       0.002191
#
#                   Order_Month   Revenue  Discounted_Price
# Age                  0.001701  0.000752         -0.003095
# Price               -0.001233  0.689759          0.930470
# Quantity            -0.005087  0.566865         -0.003302
# Discount_Percent    -0.003613 -0.241062         -0.319363
# Rating               0.006376 -0.000515          0.001490
# Delivery_Days       -0.000608  0.000535          0.003852
# Returned            -0.002025 -0.001021          0.000267
# Prime_Member         0.001393  0.001110          0.002219
# Seller_Rating        0.006533  0.003189          0.002191
# Order_Month          1.000000 -0.005002         -0.000618
# Revenue             -0.005002  1.000000          0.743154
# Discounted_Price    -0.000618  0.743154          1.000000

# %%
plt.figure(figsize=(13,5))
sns.heatmap(eda_df.corr(numeric_only=True) , annot=True)
# Out:
# <Axes: >

# %%
category_by_revenue = eda_df.groupby('Product_Category')['Revenue'].sum()
category_by_revenue
# Out:
# Product_Category
# Beauty         7.018730e+08
# Books          6.987037e+08
# Electronics    7.008641e+08
# Fashion        7.022623e+08
# Grocery        7.074417e+08
# Home           7.071617e+08
# Sports         7.058899e+08
# Toys           6.749714e+08
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(category_by_revenue)
plt.show()

# %%
eda_df.groupby('Product_Category')['Discount_Percent'].mean()
# Out:
# Product_Category
# Beauty         25.025065
# Books          25.222524
# Electronics    24.976351
# Fashion        25.096427
# Grocery        24.845311
# Home           24.971715
# Sports         24.962279
# Toys           25.243517
# Name: Discount_Percent, dtype: float64
