# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Downloads\amazon_ecommerce_sample_100k.csv")
eda_df = new_df.sample(n=100000, random_state=42)

# %%
eda_df.info()

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
new_df['is_returned'] = label.fit_transform(new_df['is_returned'])

# %%
new_df.drop(columns=["user_id" , "product_id"], inplace=True)
new_df.tail()

# %%
new_df.describe()

# %%
new_df.groupby("category")["subcategory"].value_counts()

# %%
brand_counts = (
    new_df.groupby("subcategory")["brand"]
          .value_counts()
          .reset_index(name="count")
)

brand_counts

# %%
eda_df.describe()

# %%
avg_price = eda_df.groupby("category")["final_price"].mean()

spend = plt.bar(avg_price.index, avg_price.values)
plt.bar_label(spend, fmt="%.0f")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Electronics mean purchase is 320% than average while beauty is 19.46% and clothing mean is 20.59%

# %%
disct_percentage = eda_df["discount"].value_counts()*100/len(eda_df)
avg_disct = eda_df.groupby("category")[disct_percentage]
spend1 = plt.bar(avg_disct.index, avg_disct.values , color='orange')
plt.bar_label(spend1, fmt="%.0f")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## The discount on Clothing is 40% while on electronics is 23%

# %%
eda_df['is_returned'].value_counts()*100/len(eda_df)

# %%
avg_returend = eda_df.groupby("category")["is_returned"].mean()*100
avg_returend

# %%
avg_returend = eda_df.groupby("subcategory")["is_returned"].mean()*100
avg_returend

# %%
avg_brand_spend = eda_df.groupby("brand")["final_price"].mean()
plt.figure(figsize=(12,5))
spend2 = plt.bar(avg_brand_spend.index, avg_brand_spend.values , color='red')
plt.bar_label(spend2, fmt="%.0f")

plt.xticks(rotation=45)
plt.show()

# %%
for i, predictor in enumerate(eda_df.drop(columns=['seller_id' , 'seller_rating'])):
    plt.figure(i)
    plt.figure(figsize=(8,4))
    sns.countplot(data=eda_df , x=predictor)
